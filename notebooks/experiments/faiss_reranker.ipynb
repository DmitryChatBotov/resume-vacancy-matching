# %%
import gc
import re
from collections import defaultdict
from pprint import pprint
from time import time

import faiss
import numpy as np
import pandas as pd
from sentence_transformers import CrossEncoder, SentenceTransformer, util
from tqdm import tqdm
from transformers import pipeline

# %% [markdown]
# ## Датасет

# %%
df = pd.read_csv(
    "/content/drive/MyDrive/resume_job_matching/Raw_Jobs.csv", delimiter=";"
)
df.head()
# Out:
#    №        id                                            title  \
# 0  1  78577559                                  Главный механик
# 1  2  78693069                                 HTML-верстальщик
# 2  3  78945452  Тренер (направление профессионального обучения)
# 3  4  79352008                          Старший механик на КСПГ
# 4  5  79406472                           System Analyst Trainee
#
#                     salary          experience                      job_type  \
# 0  от 160000 до 160000 RUR         Более 6 лет  Полная занятость,полный день
# 1           з/п не указана  От 1 года до 3 лет  Полная занятость,полный день
# 2           з/п не указана  От 1 года до 3 лет  Полная занятость,полный день
# 3           з/п не указана         Более 6 лет  Полная занятость,полный день
# 4           з/п не указана           Нет опыта        Стажировка,полный день
#
#                                          description  \
# 0  Вакансия компании:   ООО ПК Предприятие "ПИК" ...
# 1  В креативное агентство на полный рабочий день ...
# 2    Наши предложения:        самостоятельность в...
# 3    Обязанности:        _Обеспечение технически ...
# 4  IT-компания Aston - компания по разработке про...
#
#                                           key_skills               company  \
# 0                                                NaN               JCat.ru
# 1                                                NaN        Чугунова Ирина
# 2                                                NaN           Перекрёсток
# 3                                                NaN  Газпром гелий сервис
# 4  UML,SQL,Scrum,Retail,Базы данных,Kanban,Waterf...                 Aston
#
#       location date_of_post   type
# 0  Владивосток   27.03.2023  close
# 1          NaN   29.03.2023  close
# 2          NaN   18.04.2023  close
# 3          NaN   17.04.2023  close
# 4          NaN   17.04.2023  close

# %%
valid_comment_pattern = r"программист|разработчик|developer"

# %%
df["is_valid_pattern"] = df["title"].apply(
    lambda x: True
    if not isinstance(x, float)
    and re.match(valid_comment_pattern, x.lower()) is not None
    else False
)

# %%
df = df[df.is_valid_pattern == True]

# %%
def extract_information(job_description):
    responsibilities_pattern = r"\b(?:вам предстоит|вы будете|задачи|обязанности|чем необходимо заниматься)\b:(.*?)(?=\b(?:требования|требования к кандидатам|мы предлагаем|условия|требования:|мы ожидаем|наши пожелания|будет плюсом|будет преимуществом)\b|$)"
    requirements_pattern = r"\b(?:для нас важно|ждем от вас|мы ожидаем|наши пожелания|необходимые навыки|требования|требования к кандидатам|будет плюсом|будет преимуществом)\b:(.*?)(?=\b(?:мы предлагаем|условия|место работы|длительность рабочего дня)\b|$)"
    conditions_pattern = r"\b(?:мы предлагаем|условия)\b:(.*?)(?=\b(?:в ответ на оставленный отклик|образование)\b|$)"

    responsibilities_match = re.search(
        responsibilities_pattern, job_description, re.IGNORECASE | re.DOTALL
    )
    requirements_match = re.search(
        requirements_pattern, job_description, re.IGNORECASE | re.DOTALL
    )
    conditions_match = re.search(
        conditions_pattern, job_description, re.IGNORECASE | re.DOTALL
    )

    responsibilities = (
        responsibilities_match.group(1).strip() if responsibilities_match else None
    )
    requirements = requirements_match.group(1).strip() if requirements_match else None
    conditions = conditions_match.group(1).strip() if conditions_match else None

    return responsibilities, requirements, conditions

# %%
responsabilities, req, cond = list(), list(), list()

# %%
for row in tqdm(df["description"]):
    responsability, requirements, conditions = extract_information(row)
    responsabilities.append(responsability)
    req.append(requirements)
    cond.append(conditions)
# Out:
# 100%|██████████| 1219/1219 [00:00<00:00, 2439.56it/s]

# %%
df["responsabilities"] = responsabilities
df["requirements"] = req
df["conditions"] = cond

# %%
del responsabilities
del req
del cond
gc.collect()
# Out:
# 265

# %%
vacancy_text = defaultdict(str)
for idx, row in df.iterrows():
    vacancy_text[
        idx
    ] = f"Профессия: {row['title']}. Ключевые навыки: {row['key_skills']}. Обязанности: {row['responsabilities']}. Требования: {row['requirements']}. Условия {row['conditions']}"

# %%
df["text"] = df.index.map(vacancy_text)

# %% [markdown]
# # Алгоритм работы поиска резюме по вакансии

# %% [markdown]
# Алгоритм состоит из 2 шагов:
#
# 1. Превращаем текста в векторы с помощью энкодера и загружаем его в faiss. В качестве энкодера будем использовать intfloat/multilingual-e5-large
# 2. Делаем реранжирование с помощью кросс-энкодера

# %%
model = SentenceTransformer("intfloat/multilingual-e5-large")

# %%
query = """Программист C++, Web-программист, разработчик аппаратуры,.Опыт работы 5 лет 8 месяцев  Март 2019 — по настоящее время 3 месяца Удаленная работа Обнинск Web-программист Доработка сайта www.autolarek24.ru  Октябрь 2013 — по настоящее время 5 лет 8 месяцев АО «ГНЦ РФ – ФЭИ» Обнинск , www.ippe.ru Энергетика ... Атомная энергетика (генерация электроэнергии, АЭС) Инженер-программист Разработка ПО для операционных систем жесткого реального времени. Разработка драйверов, многопоточных приложений, клиент-серверных приложений. Разработка микропроцессорных систем. Работа с промышленными интерфейсами и протоколами: ModBus, CAN, RS422/485. Разработка документации ПО. Работа с измерительной аппаратурой с очень высокой точностью измерения и написание ПО для мониторинга и фильтрации измерений, а так же участие в разработке, настройке и тестировании данной аппаратуры.  Июнь 2017 — Ноябрь  2017 6 месяцев ООО "Персона" Обнинск Информационные технологии, системная интеграция, интернет ... Разработка программного обеспечения Веб-разработчик Разработка веб-сайтов, концепция MVC, командная разработка (Git), Laravel. Проект www.combeep.com"""

# %%
encoded_data = model.encode(df.text.tolist())
encoded_data = np.asarray(encoded_data.astype("float32"))
index = faiss.IndexIDMap(faiss.IndexFlatIP(1024))
index.add_with_ids(encoded_data, np.array(range(0, len(df))))
faiss.write_index(index, "vacancy.index")

# %% [markdown]
# ## Faiss - отбираем кандидатов

# %%
def fetch_vacancy_info(dataframe_idx):
    info = df.iloc[dataframe_idx]
    meta_dict = dict()
    meta_dict["title"] = info["title"]
    meta_dict["text"] = info["text"][:1024]
    meta_dict['vacancy_idx'] = dataframe_idx
    return meta_dict


def search(query, top_k, index, model):
    t = time()
    query_vector = model.encode([query])
    top_k = index.search(query_vector, top_k)
    print(">>>> Results in Total Time: {}".format(time() - t))
    top_k_ids = top_k[1].tolist()[0]
    top_k_ids = list(np.unique(top_k_ids))
    results = [fetch_vacancy_info(idx) for idx in top_k_ids]
    return results

# %%
results = search(query, top_k=5, index=index, model=model)
print("\n")
for result in results:
    print("\t", result)
# Out:
# >>>> Results in Total Time: 0.06160378456115723
#
#
# 	 {'title': 'Программист-разработчик', 'text': 'Профессия: Программист-разработчик. Ключевые навыки: Python,Работа с базами данных,C++,Алгоритмы и структуры данных. Обязанности: разрабатывать оборудование и по для двухстороннего стрима данных в последовательных и распределенных сетях, тренировка алгоритмов под текущие нужды.   Рассматриваются только кандидаты для оффлайн работы   Договор, пятидневка с 9 до18 центральных район. Требования: опыт работы с микроконтроллерами, опыт самостоятельной разработки, электроника   Обязанности: разрабатывать оборудование и по для двухстороннего стрима данных в последовательных и распределенных сетях, тренировка алгоритмов под текущие нужды.   Рассматриваются только кандидаты для оффлайн работы   Договор, пятидневка с 9 до18 центральных район. Условия None', 'vacancy_idx': 115}
# 	 {'title': 'Программист C/С++', 'text': 'Профессия: Программист C/С++. Ключевые навыки: Linux,C/C++,C++,CMake,Git,Boost,doctest,liburing,nfs,network programming. Обязанности: Анализ требований, участие в разработке технических решений.     Декомпозиция задач, планирование, оценка.     Имплементация с использованием языка C++     Ревью кода. Требования: Опыт программирования с использованием C++ - от 3 лет. (Linux)     Опыт командной работы (код-ревью, дизайн-ревью)     Ответственность, инициативность.     Коммуникабельность  Желательно:      Опыт разработки файловых систем, блочных хранилищ.     Опыт профилирования и оптимизации производительности кода.     Опыт разработки драйверов, модулей ядра Linux     Опыт модульного тестирования C++ кода (google test, doctest). Условия Официальное трудоустройство, конкурентная "белая" заработная плата . Финальная сумма - по результатам собеседования.     Работа в продуктовой компании, ориентированной на результат.     Периодическая индексация заработной платы.     Премирование - по результатам отчетного период', 'vacancy_idx': 489}
# 	 {'title': 'Программист С/С++ (1430)', 'text': 'Профессия: Программист С/С++ (1430). Ключевые навыки: Linux,Git,C/C++,POSIX,ГОСТ,Qt. Обязанности: разработка программного обеспечения, связанного с программно-аппаратными бортовыми системами управления       решение комплексных проблем по наладке и внедрению программного продукта       участие в пусконаладочных мероприятиях       поддержка ранее существующих проектов.. Требования: высшее или неполное высшее техническое образование       уверенное владение С/С++, понимание базовых механизмов языка (типизация, работа с памятью, потоки, ОПП)       уверенное владение фреймворком Qt (5.8+), понимание работы с потоками и асинхронностью в рамках фреймворка       уверенные навыки использования ОС Debian (или ее производными)       готовность к командировкам       разработка программной документации по ГОСТ (руководство оператора, руководство системного программиста, описание программы).    Будет плюсом:        навыки работы с git      навыки системного программирование в среде ОС Linux: написание модулей ядра, работа', 'vacancy_idx': 657}
# 	 {'title': 'Программист/Разработчик C#/.NET', 'text': 'Профессия: Программист/Разработчик C#/.NET. Ключевые навыки: С#,MS SQL Server,PostgreSQL. Обязанности: None. Требования: Высшее техническое образование, либо в том числе студент      Опыт разработки приложений на С# /.NET      Опыт работы с СУБД (MS SQL Server и PostgreSQL)      Знание принципов ООП, паттернов проектирования приложений      Хорошая алгоритмическая база.    Будет плюсом:        Опыт разработки веб-приложений на ASP.NET      Знания в области администрирования Linux      Понимание особенностей кроссплатформенной разработки. Условия Работу в стабильной, развивающейся компании      Официальная заработная плата, обсуждается на собеседовании      Оформление по ТК РФ с первого рабочего дня      Медицинский полис ДМС расширенного формата за счет компании. Льготные условия оформления ДМС для членов семьи        Территориально: офис в г. Обнинск  также рассматриваем кандидатов из других регионов с возможностью полностью удаленной работы        Интересные проекты      Возможность профессионального роста ', 'vacancy_idx': 856}
# 	 {'title': 'Программист С++', 'text': 'Профессия: Программист С++. Ключевые навыки: Qt,Debian,Astra Linux,SQL,STL,Multithread Programming,MS Visual C++,OPC,TCP/IP. Обязанности: .      Разработка специализированного кросс-платформенного клиент-серверного ПО в среде QT. Требования: Обязательно:        опыт разработки ПО на базе клиент-серверной архитектуры под Linux     опыт разработки с использованием QT     практические навыки написания многопоточного кода     Желательно:        опыт разработки под Windows (MS Visual C++)     знание протоколов OPC UA/DA, MODBUS, SNMP, MEC 870-5-101/104      знание основных сетевых протоколов, технологий, шифрования (TCP/IP, UDP, ARP, ICMP, HTTP, HTTPS)      опыт написания библиотек     знание winapi, SQL, PostgreSQL, MS SQL Server, ODBC      английский язык на уровне чтения документации.. Условия Трудоустройство по ТК РФ     _  Работа может осуществляться в удаленном режиме  _     Размер заработной платы обсуждается индивидуально по результатам собеседования      Испытательный срок 3 мес.    Обязанности:  .      Р', 'vacancy_idx': 881}

# %% [markdown]
# ## 2. Cross Encoder

# %%
cross_model = CrossEncoder("PitKoro/cross-encoder-ru-msmarco-passage", max_length=2048)

# %%
def cross_score(model_inputs):
    scores = cross_model.predict(model_inputs)
    return scores

# %%
model_inputs = [[query, item["text"]] for item in results]
scores = cross_score(model_inputs)
# Sort the scores in decreasing order
ranked_results = [
    {"Title": inp["title"], "Text": inp["text"], "Score": score}
    for inp, score in zip(results, scores)
]
ranked_results = sorted(ranked_results, key=lambda x: x["Score"], reverse=True)

# %%
print("\n")
for result in ranked_results:
    print("\t", pprint(result))
# Out:
# {'Score': 0.49219885,
#  'Text': 'Профессия: Программист С++. Ключевые навыки: Qt,Debian,Astra '
#          'Linux,SQL,STL,Multithread Programming,MS Visual C++,OPC,TCP/IP. '
#          'Обязанности: .      Разработка специализированного '
#          'кросс-платформенного клиент-серверного ПО в среде QT. Требования: '
#          'Обязательно:        опыт разработки ПО на базе клиент-серверной '
#          'архитектуры под Linux     опыт разработки с использованием QT     '
#          'практические навыки написания многопоточного кода     '
#          'Желательно:        опыт разработки под Windows (MS Visual C++)     '
#          'знание протоколов OPC UA/DA, MODBUS, SNMP, MEC 870-5-101/104      '
#          'знание основных сетевых протоколов, технологий, шифрования (TCP/IP, '
#          'UDP, ARP, ICMP, HTTP, HTTPS)      опыт написания библиотек     '
#          'знание winapi, SQL, PostgreSQL, MS SQL Server, ODBC      английский '
#          'язык на уровне чтения документации.. Условия Трудоустройство по ТК '
#          'РФ     _  Работа может осуществляться в удаленном режиме  _     '
#          'Размер заработной платы обсуждается индивидуально по результатам '
#          'собеседования      Испытательный срок 3 мес.    Обязанности:  .      '
#          'Р',
#  'Title': 'Программист С++'}
# 	 None
# {'Score': 0.3472393,
#  'Text': 'Профессия: Программист С/С++ (1430). Ключевые навыки: '
#          'Linux,Git,C/C++,POSIX,ГОСТ,Qt. Обязанности: разработка программного '
#          'обеспечения, связанного с программно-аппаратными бортовыми системами '
#          'управления       решение комплексных проблем по наладке и внедрению '
#          'программного продукта       участие в пусконаладочных '
#          'мероприятиях       поддержка ранее существующих проектов.. '
#          'Требования: высшее или неполное высшее техническое образование       '
#          'уверенное владение С/С++, понимание базовых механизмов языка '
#          '(типизация, работа с памятью, потоки, ОПП)       уверенное владение '
#          'фреймворком Qt (5.8+), понимание работы с потоками и асинхронностью '
#          'в рамках фреймворка       уверенные навыки использования ОС Debian '
#          '(или ее производными)       готовность к командировкам       '
#          'разработка программной документации по ГОСТ (руководство оператора, '
#          'руководство системного программиста, описание программы).    Будет '
#          'плюсом:        навыки работы с git      навыки системного '
#          'программирование в среде ОС Linux: написание модулей ядра, работа',
#  'Title': 'Программист С/С++ (1430)'}
# 	 None
# {'Score': 0.33903688,
#  'Text': 'Профессия: Программист/Разработчик C#/.NET. Ключевые навыки: С#,MS '
#          'SQL Server,PostgreSQL. Обязанности: None. Требования: Высшее '
#          'техническое образование, либо в том числе студент      Опыт '
#          'разработки приложений на С# /.NET      Опыт работы с СУБД (MS SQL '
#          'Server и PostgreSQL)      Знание принципов ООП, паттернов '
#          'проектирования приложений      Хорошая алгоритмическая база.    '
#          'Будет плюсом:        Опыт разработки веб-приложений на ASP.NET      '
#          'Знания в области администрирования Linux      Понимание особенностей '
#          'кроссплатформенной разработки. Условия Работу в стабильной, '
#          'развивающейся компании      Официальная заработная плата, '
#          'обсуждается на собеседовании      Оформление по ТК РФ с первого '
#          'рабочего дня      Медицинский полис ДМС расширенного формата за счет '
#          'компании. Льготные условия оформления ДМС для членов семьи        '
#          'Территориально: офис в г. Обнинск  также рассматриваем кандидатов из '
#          'других регионов с возможностью полностью удаленной работы        '
#          'Интересные проекты      Возможность профессионального роста ',
#  'Title': 'Программист/Разработчик C#/.NET'}
# 	 None
# {'Score': 0.26016504,
#  'Text': 'Профессия: Программист C/С++. Ключевые навыки: '
#          'Linux,C/C++,C++,CMake,Git,Boost,doctest,liburing,nfs,network '
#          'programming. Обязанности: Анализ требований, участие в разработке '
#          'технических решений.     Декомпозиция задач, планирование, '
#          'оценка.     Имплементация с использованием языка C++     Ревью кода. '
#          'Требования: Опыт программирования с использованием C++ - от 3 лет. '
#          '(Linux)     Опыт командной работы (код-ревью, дизайн-ревью)     '
#          'Ответственность, инициативность.     Коммуникабельность  '
#          'Желательно:      Опыт разработки файловых систем, блочных '
#          'хранилищ.     Опыт профилирования и оптимизации производительности '
#          'кода.     Опыт разработки драйверов, модулей ядра Linux     Опыт '
#          'модульного тестирования C++ кода (google test, doctest). Условия '
#          'Официальное трудоустройство, конкурентная "белая" заработная плата . '
#          'Финальная сумма - по результатам собеседования.     Работа в '
#          'продуктовой компании, ориентированной на результат.     '
#          'Периодическая индексация заработной платы.     Премирование - по '
#          'результатам отчетного период',
#  'Title': 'Программист C/С++'}
# 	 None
# {'Score': 0.11581372,
#  'Text': 'Профессия: Программист-разработчик. Ключевые навыки: Python,Работа с '
#          'базами данных,C++,Алгоритмы и структуры данных. Обязанности: '
#          'разрабатывать оборудование и по для двухстороннего стрима данных в '
#          'последовательных и распределенных сетях, тренировка алгоритмов под '
#          'текущие нужды.   Рассматриваются только кандидаты для оффлайн '
#          'работы   Договор, пятидневка с 9 до18 центральных район. Требования: '
#          'опыт работы с микроконтроллерами, опыт самостоятельной разработки, '
#          'электроника   Обязанности: разрабатывать оборудование и по для '
#          'двухстороннего стрима данных в последовательных и распределенных '
#          'сетях, тренировка алгоритмов под текущие нужды.   Рассматриваются '
#          'только кандидаты для оффлайн работы   Договор, пятидневка с 9 до18 '
#          'центральных район. Условия None',
#  'Title': 'Программист-разработчик'}
# 	 None

# %% [markdown]
# ## Метрики

# %% [markdown]
# Посчитаем метрики на размеченном датасете для IT вакансий

# %%
labeling = pd.read_csv("/content/drive/MyDrive/resume_job_matching/labeling.csv")

# %%
top100_vacancies = pd.read_csv('/content/drive/MyDrive/resume_job_matching/random100vac.csv')
top100_vacancies.head()
# Out:
#       №        id                           Должность  \
# 0   394  79011638                  Разработчик Kotlin
# 1   426  79280145                Разработчик Bitrix24
# 2  1233  79472031  Программист 1С (начальный уровень)
# 3  1429  79600291           Программист станков с ЧПУ
# 4  2336  78562452   Разработчик / аналитик Qlik Sense
#
#                   Зарплата         Опыт работы                     Занятость  \
# 0           з/п не указана  От 1 года до 3 лет  Полная занятость,полный день
# 1           з/п не указана       От 3 до 6 лет  Полная занятость,полный день
# 2             от 60000 RUR  От 1 года до 3 лет  Полная занятость,полный день
# 3             от 35000 RUR  От 1 года до 3 лет  Полная занятость,полный день
# 4  от 130000 до 150000 RUR       От 3 до 6 лет  Полная занятость,полный день
#
#                                    Описание вакансии  \
# 0    Marlerino Group   – молодая, развивающаяся I...
# 1    Обязанности:         Техническая поддержка П...
# 2  В компанию, имеющую аккредитацию ИТ компаний, ...
# 3    Обязанности:        Программирование станков...
# 4    Задачи:    • Участие в формировании стратеги...
#
#                                      Ключевые навыки            Компания  \
# 0  Java,Мобильные приложения,ООП,Kotlin,Android S...     Marlerino Group
# 1                        ключевые навыки отсутствуют  Медицинские товары
# 2  1С: Зарплата и управление персоналом,1С: Бухга...             МАКСИМА
# 3                        ключевые навыки отсутствуют             КНИИТМУ
# 4  Qlik Sense,BI,QlikView,Анализ бизнес показател...          А-Контракт
#
#                            Город Обновление резюме    Тип  is_valid_pattern  \
# 0                         Россия        06.04.2023  close              True
# 1                         Россия        13.04.2023  close              True
# 2                         Россия        18.04.2023  close              True
# 3  Калуга, улица Карла Маркса, 4        20.04.2023  close              True
# 4                         Россия        27.03.2023  close              True
#
#                                                 text
# 0  Разработчик Kotlin.   Marlerino Group   – моло...
# 1  Разработчик Bitrix24.   Обязанности:         Т...
# 2  Программист 1С (начальный уровень). В компанию...
# 3  Программист станков с ЧПУ.   Обязанности:     ...
# 4  Разработчик / аналитик Qlik Sense.   Задачи:  ...

# %%
top100_resume = pd.read_csv('/content/drive/MyDrive/resume_job_matching/random100resume.csv')
top100_resume.head()
# Out:
#                                     Пол, возраст          ЗП  \
# 0     Мужчина ,  27 лет , родился 8 августа 1991  70000 руб.
# 1      Мужчина ,  24 года , родился 14 июля 1994  70000 руб.
# 2  Женщина ,  44 года , родилась 15 октября 1974  50000 руб.
# 3      Мужчина ,  24 года , родился 13 июня 1994  30000 руб.
# 4      Мужчина ,  35 лет , родился 12 марта 1984   1800 руб.
#
#                            Ищет работу на должность:  \
# 0  Программист C++, Web-программист, разработчик ...
# 1                                        Программист
# 2                                        Программист
# 3                            Программист-разработчик
# 4                                   Программист 1С 8
#
#                         Город, переезд, командировки  \
# 0  Обнинск , готов к переезду , готов к командиро...
# 1  Тюмень , не готов к переезду , не готов к кома...
# 2  Губкин , готова к переезду , готова к командир...
# 3  Ростов-на-Дону , готов к переезду , готов к ко...
# 4  Москва ,  м. Выхино , не готов к переезду , не...
#
#                                            Занятость  \
# 0              частичная занятость, полная занятость
# 1  проектная работа, частичная занятость, полная ...
# 2                                   полная занятость
# 3                                   полная занятость
# 4              частичная занятость, проектная работа
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, уд...
# 1       удаленная работа, гибкий график, полный день
# 2      полный день, сменный график, удаленная работа
# 3                                        полный день
# 4                    гибкий график, удаленная работа
#
#                                          Опыт работы  \
# 0  Опыт работы 5 лет 8 месяцев  Март 2019 — по на...
# 1  Опыт работы 3 года 2 месяца  Декабрь 2018 — по...
# 2  Опыт работы 12 лет 5 месяцев  Декабрь 2016 — А...
# 3  Опыт работы 2 года 11 месяцев  Июль 2016 — по ...
# 4  Опыт работы 16 лет 2 месяца  Декабрь 2007 — по...
#
#                      Последнее/нынешнее место работы  \
# 0                                   Удаленная работа
# 1  Индивидуальное предпринимательство / частная п...
# 2                               ООО"ТД Молочный мир"
# 3                                          ООО "АПС"
# 4  Комплексное сопровождение клиентов по автомати...
#
#   Последняя/нынешняя должность  \
# 0              Web-программист
# 1                  Программист
# 2       Торговый представитель
# 3                      Инженер
# 4               Программист 1С
#
#                                    Образование и ВУЗ Обновление резюме  \
# 0  Высшее образование 2018 ИАТЭ НИЯУ МИФИ Институ...  17.04.2019 16:49
# 1  Высшее образование 2017 НГИИ (бывш. НИИ) Факул...  13.05.2019 12:01
# 2  Высшее образование 2011 Московский Государстве...  12.04.2019 12:54
# 3  Высшее образование (Магистр) 2018  Ростовский ...  12.04.2019 11:52
# 4  Высшее образование 2008 Южно-Российский госуда...  07.05.2019 11:34
#
#                              Авто  is_valid_pattern  \
# 0  Имеется собственный автомобиль              True
# 1                      Не указано              True
# 2                      Не указано              True
# 3                      Не указано              True
# 4                      Не указано              True
#
#                                                 text
# 0  Программист C++, Web-программист, разработчик ...
# 1  Программист.Опыт работы 3 года 2 месяца  Декаб...
# 2  Программист.Опыт работы 12 лет 5 месяцев  Дека...
# 3  Программист-разработчик.Опыт работы 2 года 11 ...
# 4  Программист 1С 8.Опыт работы 16 лет 2 месяца  ...

# %%
labeling.head()
# Out:
#    Unnamed: 0  is_relevant  score  \
# 0           0            0      2
# 1           1            0      0
# 2           2            0      0
# 3           3            0      0
# 4           4            0      2
#
#                                       interpretation  resume_index  \
# 0  Вакансия не подходит, поскольку опыт работы в ...            83
# 1  Вакансия не соответствует опыту кандидата, так...            83
# 2  Вакансия не релевантна, поскольку требуется сп...            83
# 3  Отсутствие в резюме упоминания о знании PHP, L...            83
# 4  Не подходит: опыт работы соискателя значительн...            83
#
#    vacancy_index
# 0              4
# 1             63
# 2              3
# 3             36
# 4             44

# %%
vacancies = top100_vacancies[top100_vacancies.index.isin(labeling.vacancy_index.unique())]
vacancies.head()
# Out:
#       №        id                                          Должность  \
# 1   426  79280145                               Разработчик Bitrix24
# 3  1429  79600291                          Программист станков с ЧПУ
# 4  2336  78562452                  Разработчик / аналитик Qlik Sense
# 5  2350  79071089           Разработчик фронтенда в команду API Карт
# 6  2595  78050064  Программист -тестировщик (отдел автотестирования)
#
#                   Зарплата         Опыт работы                     Занятость  \
# 1           з/п не указана       От 3 до 6 лет  Полная занятость,полный день
# 3             от 35000 RUR  От 1 года до 3 лет  Полная занятость,полный день
# 4  от 130000 до 150000 RUR       От 3 до 6 лет  Полная занятость,полный день
# 5           з/п не указана       От 3 до 6 лет  Полная занятость,полный день
# 6    от 46000 до 92000 RUR  От 1 года до 3 лет  Полная занятость,полный день
#
#                                    Описание вакансии  \
# 1    Обязанности:         Техническая поддержка П...
# 3    Обязанности:        Программирование станков...
# 4    Задачи:    • Участие в формировании стратеги...
# 5  Мы разрабатываем JavaScript API Яндекс Карт. Н...
# 6  Тензор - это аккредитованная IT-компания: боле...
#
#                                      Ключевые навыки            Компания  \
# 1                        ключевые навыки отсутствуют  Медицинские товары
# 3                        ключевые навыки отсутствуют             КНИИТМУ
# 4  Qlik Sense,BI,QlikView,Анализ бизнес показател...          А-Контракт
# 5                    JavaScript,TypeScript,React,API              Яндекс
# 6                        ключевые навыки отсутствуют              Тензор
#
#                                Город Обновление резюме    Тип  \
# 1                             Россия        13.04.2023  close
# 3      Калуга, улица Карла Маркса, 4        20.04.2023  close
# 4                             Россия        27.03.2023  close
# 5  Москва, Садовническая улица, 82с2        09.04.2023  close
# 6                             Россия        10.04.2023  close
#
#    is_valid_pattern                                               text
# 1              True  Разработчик Bitrix24.   Обязанности:         Т...
# 3              True  Программист станков с ЧПУ.   Обязанности:     ...
# 4              True  Разработчик / аналитик Qlik Sense.   Задачи:  ...
# 5              True  Разработчик фронтенда в команду API Карт. Мы р...
# 6              True  Программист -тестировщик (отдел автотестирован...

# %%
resumes  = top100_resume[top100_resume.index.isin(labeling.resume_index.unique())]
resumes.head()
# Out:
#                                     Пол, возраст           ЗП  \
# 1      Мужчина ,  24 года , родился 14 июля 1994   70000 руб.
# 6   Мужчина ,  22 года , родился 27 октября 1996  100000 руб.
# 26   Мужчина ,  48 лет , родился 17 октября 1970   30000 руб.
# 30   Мужчина ,  36 лет , родился 14 февраля 1983   60000 руб.
# 33   Мужчина ,  31 год , родился 21 октября 1987   50000 руб.
#
#    Ищет работу на должность:  \
# 1                Программист
# 6            Программист С++
# 26  Программист, оператор ПК
# 30   Программист-разработчик
# 33            Разработчик ПО
#
#                          Город, переезд, командировки  \
# 1   Тюмень , не готов к переезду , не готов к кома...
# 6   Москва ,  м. Войковская , не готов к переезду ...
# 26  Санкт-Петербург ,  м. Парк Победы , готов к пе...
# 30  Москва ,  м. Алтуфьево , готов к переезду (Бел...
# 33  Набережные Челны , готов к переезду , готов к ...
#
#                                             Занятость  \
# 1   проектная работа, частичная занятость, полная ...
# 6               проектная работа, частичная занятость
# 26  проектная работа, стажировка, частичная занято...
# 30  частичная занятость, проектная работа, полная ...
# 33  частичная занятость, проектная работа, полная ...
#
#                                                График  \
# 1        удаленная работа, гибкий график, полный день
# 6                     удаленная работа, гибкий график
# 26  удаленная работа, гибкий график, полный день, ...
# 30                                   удаленная работа
# 33  полный день, сменный график, вахтовый метод, у...
#
#                                           Опыт работы  \
# 1   Опыт работы 3 года 2 месяца  Декабрь 2018 — по...
# 6   Опыт работы 1 год 2 месяца  Программист С++ 10...
# 26  Опыт работы 23 года 6 месяцев  Март 1995 — Авг...
# 30  Опыт работы 9 лет 10 месяцев  Август 2018 — Ма...
# 33  Опыт работы 6 лет 2 месяца  Разработчик ПО 50 ...
#
#                       Последнее/нынешнее место работы  \
# 1   Индивидуальное предпринимательство / частная п...
# 6                                      Design Dossier
# 26                          ГК Бюллетень Недвижимости
# 30                                        ОАО "Вента"
# 33                                          БАРС Груп
#
#    Последняя/нынешняя должность  \
# 1                   Программист
# 6                   Программист
# 26                  Программист
# 30                  Программист
# 33              Web-разработчик
#
#                                     Образование и ВУЗ Обновление резюме  \
# 1   Высшее образование 2017 НГИИ (бывш. НИИ) Факул...  13.05.2019 12:01
# 6   Неоконченное высшее образование 2020  Московск...  22.04.2019 16:06
# 26  Неоконченное высшее образование 1992  Санкт-Пе...  07.05.2019 21:02
# 30  Высшее образование 2005  Уральский федеральный...  17.04.2019 15:13
# 33  Высшее образование (Бакалавр) 2017  Филиал Каз...  22.04.2019 08:59
#
#           Авто  is_valid_pattern  \
# 1   Не указано              True
# 6   Не указано              True
# 26  Не указано              True
# 30  Не указано              True
# 33  Не указано              True
#
#                                                  text
# 1   Программист.Опыт работы 3 года 2 месяца  Декаб...
# 6   Программист С++.Опыт работы 1 год 2 месяца  Пр...
# 26  Программист, оператор ПК.Опыт работы 23 года 6...
# 30  Программист-разработчик.Опыт работы 9 лет 10 м...
# 33  Разработчик ПО.Опыт работы 6 лет 2 месяца  Раз...

# %% [markdown]
# Построим модель на датасете резюме

# %%
encoded_data = model.encode(vacancies.text.tolist())
encoded_data = np.asarray(encoded_data.astype("float32"))
index = faiss.IndexIDMap(faiss.IndexFlatIP(1024))
index.add_with_ids(encoded_data, np.array(range(0, len(vacancies))))
faiss.write_index(index, "vacancy_metrics.index")

# %%
def get_results_by_query(query, top_k: int = 5):
  results = search(query, top_k=top_k, index=index, model=model)
  model_inputs = [[query, item["text"]] for item in results]
  scores = cross_score(model_inputs)
  ranked_results = [
      {"Title": inp["title"], "Text": inp["text"], "Score": score, 'inner_idx': inp['vacancy_idx']}
      for inp, score in zip(results, scores)
  ]
  ranked_results = sorted(ranked_results, key=lambda x: x["Score"], reverse=True)
  return ranked_results

# %% [markdown]
# Посчитаем результаты. Будем предсказывать топ10 вакансий по каждому резюме

# %%
result_dict = defaultdict(list)
for idx, row in resumes.iterrows():
  resume_inx = top100_resume.index[top100_resume.text == row['text']].tolist()[0]
  top_k = 10
  ranked_results = get_results_by_query(row['text'][:1024], top_k = top_k)
  ranked_results_internal_vac_idx = [vac['inner_idx'] for vac in ranked_results]
  internal_vac_texts = vacancies.iloc[ranked_results_internal_vac_idx]['text'].tolist()
  external_vac_indexes = top100_vacancies.index[top100_vacancies.text.isin(internal_vac_texts)].tolist()
  result_dict[resume_inx] = external_vac_indexes
# Out:
# >>>> Results in Total Time: 0.1343836784362793
# >>>> Results in Total Time: 0.09002304077148438
# >>>> Results in Total Time: 0.11592626571655273
# >>>> Results in Total Time: 0.1261446475982666
# >>>> Results in Total Time: 0.10978937149047852
# >>>> Results in Total Time: 0.10180115699768066
# >>>> Results in Total Time: 0.0744316577911377
# >>>> Results in Total Time: 0.08184504508972168
# >>>> Results in Total Time: 0.05741691589355469
# >>>> Results in Total Time: 0.07215285301208496
# >>>> Results in Total Time: 0.052852630615234375
# >>>> Results in Total Time: 0.0915677547454834
# >>>> Results in Total Time: 0.07047319412231445
# >>>> Results in Total Time: 0.0752418041229248
# >>>> Results in Total Time: 0.043642282485961914
# >>>> Results in Total Time: 0.06479501724243164

# %%
labeling_dict = defaultdict(set)
for idx, row in labeling.iterrows():
  labeling_dict[row['resume_index']].add(row['vacancy_index'])

# %%
def precision(groundtruth,predicted):
   return len(set(predicted).intersection(set(groundtruth))) / len(predicted)
def recall(groundruth, predicted):
   return len(set(predicted).intersection(set(groundtruth))) / len(groundtruth)

def f1(precision, recall):
  return (2 * (precision * recall) / (precision + recall)) if (precision + recall) > 0 else 0

# %%
precisions, recalls, f1s = list(), list(), list()
for resume_idx, vacancy_idxs in result_dict.items():
  predicted   = vacancy_idxs
  groundtruth = labeling_dict[resume_idx]
  prec = precision(groundtruth, predicted)
  rec = recall(groundtruth, predicted)
  f1s.append(f1(prec, rec))
  precisions.append(prec)
  recalls.append(rec)

print(f"Mean precision: {sum(precisions) / len(precisions)}")
print(f"Mean recall: {sum(recalls) / len(recalls)}")
print(f"Mean F1: {sum(f1s) / len(f1s)}")
# Out:
# Mean precision: 0.16875000000000004
# Mean recall: 0.1173611111111111
# Mean F1: 0.13794258373205742

# %% [markdown]
# ## Вывод

# %% [markdown]
# Нас устраивает качество работы алгоритма, поэтому возьмем его в качестве рабочего и будем выводить его в продуктив
