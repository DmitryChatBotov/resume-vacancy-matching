# %%
import gc
import re
from collections import defaultdict
from pprint import pprint

import pandas as pd
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
from umap import UMAP

# %% [markdown]
# ## Датасет

# %%
df = pd.read_csv(
    "/content/drive/MyDrive/resume_job_matching/Raw_Jobs.csv", delimiter=";"
)

# %%
df.head()
# Out:
#    №        id                                            title  \
# 0  1  78577559                                  Главный механик
# 1  2  78693069                                 HTML-верстальщик
# 2  3  78945452  Тренер (направление профессионального обучения)
# 3  4  79352008                          Старший механик на КСПГ
# 4  5  79406472                           System Analyst Trainee
#
#                     salary          experience                      job_type  \
# 0  от 160000 до 160000 RUR         Более 6 лет  Полная занятость,полный день
# 1           з/п не указана  От 1 года до 3 лет  Полная занятость,полный день
# 2           з/п не указана  От 1 года до 3 лет  Полная занятость,полный день
# 3           з/п не указана         Более 6 лет  Полная занятость,полный день
# 4           з/п не указана           Нет опыта        Стажировка,полный день
#
#                                          description  \
# 0  Вакансия компании:   ООО ПК Предприятие "ПИК" ...
# 1  В креативное агентство на полный рабочий день ...
# 2    Наши предложения:        самостоятельность в...
# 3    Обязанности:        _Обеспечение технически ...
# 4  IT-компания Aston - компания по разработке про...
#
#                                           key_skills               company  \
# 0                                                NaN               JCat.ru
# 1                                                NaN        Чугунова Ирина
# 2                                                NaN           Перекрёсток
# 3                                                NaN  Газпром гелий сервис
# 4  UML,SQL,Scrum,Retail,Базы данных,Kanban,Waterf...                 Aston
#
#       location date_of_post   type
# 0  Владивосток   27.03.2023  close
# 1          NaN   29.03.2023  close
# 2          NaN   18.04.2023  close
# 3          NaN   17.04.2023  close
# 4          NaN   17.04.2023  close

# %% [markdown]
# Отбираем только IT специальности

# %%
valid_comment_pattern = r"программист|разработчик|developer"

# %%
df["is_valid_pattern"] = df["title"].apply(
    lambda x: True
    if not isinstance(x, float)
    and re.match(valid_comment_pattern, x.lower()) is not None
    else False
)

# %%
df = df[df.is_valid_pattern == True]

# %% [markdown]
# Парсим описание вакансии, извлекаем обязанности, требования и условия

# %%
responsabilities, req, cond = list(), list(), list()

# %%
def extract_information(job_description):
    responsibilities_pattern = r"\b(?:вам предстоит|вы будете|задачи|обязанности|чем необходимо заниматься)\b:(.*?)(?=\b(?:требования|требования к кандидатам|мы предлагаем|условия|требования:|мы ожидаем|наши пожелания|будет плюсом|будет преимуществом)\b|$)"
    requirements_pattern = r"\b(?:для нас важно|ждем от вас|мы ожидаем|наши пожелания|необходимые навыки|требования|требования к кандидатам|будет плюсом|будет преимуществом)\b:(.*?)(?=\b(?:мы предлагаем|условия|место работы|длительность рабочего дня)\b|$)"
    conditions_pattern = r"\b(?:мы предлагаем|условия)\b:(.*?)(?=\b(?:в ответ на оставленный отклик|образование)\b|$)"

    responsibilities_match = re.search(
        responsibilities_pattern, job_description, re.IGNORECASE | re.DOTALL
    )
    requirements_match = re.search(
        requirements_pattern, job_description, re.IGNORECASE | re.DOTALL
    )
    conditions_match = re.search(
        conditions_pattern, job_description, re.IGNORECASE | re.DOTALL
    )

    responsibilities = (
        responsibilities_match.group(1).strip() if responsibilities_match else None
    )
    requirements = requirements_match.group(1).strip() if requirements_match else None
    conditions = conditions_match.group(1).strip() if conditions_match else None

    return responsibilities, requirements, conditions

# %%
for row in tqdm(df["description"]):
    responsability, requirements, conditions = extract_information(row)
    responsabilities.append(responsability)
    req.append(requirements)
    cond.append(conditions)
# Out:
# 100%|██████████| 1219/1219 [00:00<00:00, 3797.56it/s]

# %%
df["responsabilities"] = responsabilities
df["requirements"] = req
df["conditions"] = cond

# %%
del responsabilities
del req
del cond
gc.collect()
# Out:
# 123394

# %% [markdown]
# Делаем текст, который передадим эмбеддеру в bertopic

# %%
vacancy_text = defaultdict(str)
for idx, row in df.iterrows():
    vacancy_text[
        idx
    ] = f"Профессия: {row['title']}. Ключевые навыки: {row['key_skills']}. Обязанности: {row['responsabilities']}. Требования: {row['requirements']}. Условия {row['conditions']}"

# %%
df["text"] = df.index.map(vacancy_text)

# %%
docs = df["text"].tolist()
del df
gc.collect()
# Out:
# 0

# %% [markdown]
# ## BerTopic

# %% [markdown]
# Создаем модель BerTopic. В качестве эмбеддера будем использовать multilingual-e5-large, потому что он себя показал наилучшим образом при подсчете метрик

# %%
keybert = KeyBERTInspired()
umap_model = UMAP(n_neighbors=15, n_components=10, metric="cosine", low_memory=False)
representation_model = MaximalMarginalRelevance(diversity=0.3)
models = [keybert, representation_model]

embedding_model = SentenceTransformer("intfloat/multilingual-e5-large")
hdbscan_model = HDBSCAN(metric="euclidean", prediction_data=True)
topic_model = BERTopic(
    representation_model=models,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    embedding_model=embedding_model,
    calculate_probabilities=False,
    low_memory=True,
    top_n_words=25,
    verbose=False,
    nr_topics="auto",
    language="multilingual",
)

topics, probs = topic_model.fit_transform(docs)

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d951dfbe-860c-48b5-9d24-26d05b28b90a" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d951dfbe-860c-48b5-9d24-26d05b28b90a")) {                    Plotly.newPlot(                        "d951dfbe-860c-48b5-9d24-26d05b28b90a",                        [{"customdata":[[0,"\u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0438\u0441\u0442 | \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u044f | \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 | \u043f\u0440\u043e\u0444\u0435\u0441\u0441\u0438\u044f | \u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u0447\u0438\u043a",639],[1,"\u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0438\u0441\u0442 | \u043f\u0440\u043e\u0444\u0435\u0441\u0441\u0438\u044f | \u043d\u0430\u0432\u044b\u043a\u0438 | \u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u0447\u0438\u043a | \u0442\u0440\u0435\u0431\u043e\u0432\u0430\u043d\u0438\u044f",50],[2,"\u043a\u0443\u0440\u0441\u043e\u0432 | \u043e\u0431\u0443\u0447\u0435\u043d\u0438\u0435 | \u043e\u0431\u0443\u0447\u0435\u043d\u0438\u044f | \u043e\u0431\u0443\u0447\u0430\u044e\u0449\u0438\u0445 | \u0443\u0447\u0435\u0431\u043d\u044b\u0445",49],[3,"\u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0438\u0441\u0442 | \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c | \u0444\u0440\u0435\u0437\u0435\u0440\u043d\u044b\u0435 | \u0444\u0440\u0435\u0437\u0435\u0440\u043d\u044b\u0445 | \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u044b",45],[4,"\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0443\u044e | \u0443\u0434\u0430\u043b\u0435\u043d\u043d\u043e | \u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f | \u0443\u0434\u0430\u043b\u0451\u043d\u043d\u043e | frontend",20],[5,"\u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u0447\u0438\u043a | \u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0435 | unity3d | \u043e\u043f\u044b\u0442\u043d\u044b\u0439 | \u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0438",17],[6,"\u0442\u0435\u0441\u0442\u0438\u0440\u043e\u0432\u0449\u0438\u043a | \u0430\u0432\u0442\u043e\u0442\u0435\u0441\u0442\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u044f | \u0430\u0432\u0442\u043e\u0442\u0435\u0441\u0442\u043e\u0432 | \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0438\u0441\u0442 | \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u044f",13],[7,"\u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u0447\u0438\u043a | \u043e\u0442\u0447\u0435\u0442\u043d\u043e\u0441\u0442\u0438 | \u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0435 | \u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0445 | \u0442\u0440\u0435\u0431\u043e\u0432\u0430\u043d\u0438\u044f",12],[8,"\u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u0447\u0438\u043a | \u0434\u043e\u043a\u0443\u043c\u0435\u043d\u0442\u0430\u0446\u0438\u0438 | \u043a\u043e\u043d\u0441\u0442\u0440\u0443\u043a\u0442\u043e\u0440\u0441\u043a\u043e\u0439 | \u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u043a\u0438 | \u0434\u043e\u043a\u0443\u043c\u0435\u043d\u0442\u0430\u0446\u0438\u044f",11],[9,"\u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0438\u0441\u0442 | \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u044f | \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 | \u043c\u0438\u043a\u0440\u043e\u043a\u043e\u043d\u0442\u0440\u043e\u043b\u043b\u0435\u0440\u043e\u0432 | \u043f\u0440\u043e\u0433\u0440\u0430\u043c\u043c\u043d\u043e\u0433\u043e",11],[10,"\u0440\u0430\u0437\u0440\u0430\u0431\u043e\u0442\u0447\u0438\u043a | \u0441\u0445\u ...

# %%
topic_model.get_topics()
# Out:
# {-1: [('программист', 0.8537121),
#   ('программирования', 0.84528023),
#   ('разработчик', 0.8423854),
#   ('программирование', 0.8398908),
#   ('разработки', 0.8226284),
#   ('требования', 0.82042),
#   ('профессия', 0.81645536),
#   ('собеседования', 0.81625974),
#   ('разработка', 0.81606394),
#   ('доработка', 0.81532484)],
#  0: [('программист', 0.8485298),
#   ('программирования', 0.83769786),
#   ('программирование', 0.8301968),
#   ('профессия', 0.8223953),
#   ('разработчик', 0.8194152),
#   ('трудоустройство', 0.8162051),
#   ('1с', 0.81517124),
#   ('разработке', 0.8108654),
#   ('разработки', 0.8084177),
#   ('требования', 0.8072736)],
#  1: [('программист', 0.8384203),
#   ('профессия', 0.82382095),
#   ('навыки', 0.8222941),
#   ('разработчик', 0.8181265),
#   ('требования', 0.8157112),
#   ('ключевые', 0.8152171),
#   ('python', 0.80785406),
#   ('обязанности', 0.80665183),
#   ('данных', 0.8042709),
#   ('postgresql', 0.80245245)],
#  2: [('курсов', 0.82819754),
#   ('обучение', 0.82352537),
#   ('обучения', 0.8168303),
#   ('обучающих', 0.814839),
#   ('учебных', 0.8123432),
#   ('разработчик', 0.8089688),
#   ('электронные', 0.80791336),
#   ('разработки', 0.8073767),
#   ('персонала', 0.80733657),
#   ('образовательных', 0.8072496)],
#  3: [('программист', 0.8295912),
#   ('программ', 0.8188368),
#   ('фрезерные', 0.8186244),
#   ('фрезерных', 0.81736964),
#   ('программы', 0.8145205),
#   ('фрезерная', 0.812255),
#   ('станков', 0.80632275),
#   ('станках', 0.8043676),
#   ('токарных', 0.80330634),
#   ('станки', 0.8019962)],
#  4: [('удаленную', 0.8138125),
#   ('удаленно', 0.81295335),
#   ('удаленная', 0.8122863),
#   ('удалённо', 0.8106569),
#   ('frontend', 0.8087846),
#   ('фронтэнда', 0.8080654),
#   ('разработчик', 0.80738133),
#   ('требования', 0.8048502),
#   ('профессия', 0.8039201),
#   ('ключевые', 0.7992625)],
#  5: [('разработчик', 0.8243659),
#   ('разработке', 0.81502616),
#   ('unity3d', 0.81458724),
#   ('опытный', 0.8123486),
#   ('разработки', 0.81209385),
#   ('требования', 0.80940866),
#   ('профессия', 0.8080351),
#   ('самореализации', 0.80380255),
#   ('разработка', 0.8009768),
#   ('работу', 0.7998496)],
#  6: [('тестировщик', 0.8253803),
#   ('автотестирования', 0.81832206),
#   ('автотестов', 0.81438965),
#   ('программист', 0.812312),
#   ('программирования', 0.80990636),
#   ('тестирования', 0.805258),
#   ('тестовых', 0.79575074),
#   ('профессия', 0.78896),
#   ('квалификации', 0.7864785),
#   ('webdriver', 0.7849076)],
#  7: [('разработчик', 0.8141097),
#   ('отчетности', 0.81300306),
#   ('разработке', 0.8125929),
#   ('аналитических', 0.80995363),
#   ('требования', 0.8057863),
#   ('разработка', 0.8046069),
#   ('визуализации', 0.8016995),
#   ('профессия', 0.8006967),
#   ('навыки', 0.8004991),
#   ('аналитик', 0.7995775)],
#  8: [('разработчик', 0.83010316),
#   ('документации', 0.82372993),
#   ('конструкторской', 0.8223926),
#   ('разработки', 0.82063764),
#   ('документация', 0.8185172),
#   ('сертификации', 0.8182805),
#   ('конструкторских', 0.81806374),
#   ('проектных', 0.8172253),
#   ('разработка', 0.8141086),
#   ('проектной', 0.81216145)],
#  9: [('программист', 0.8319481),
#   ('программирования', 0.827199),
#   ('программирование', 0.82258475),
#   ('микроконтроллеров', 0.8093897),
#   ('программного', 0.80885166),
#   ('контроллеров', 0.8074277),
#   ('автоматизации', 0.80523574),
#   ('инженер', 0.80487823),
#   ('автоматизация', 0.8048223),
#   ('контроллеры', 0.80330396)],
#  10: [('разработчик', 0.8257161),
#   ('схемотехники', 0.8231465),
#   ('разработки', 0.8203094),
#   ('конструкторской', 0.814502),
#   ('транзисторов', 0.81378937),
#   ('электронных', 0.81292254),
#   ('разработка', 0.81118053),
#   ('макетирования', 0.81040406),
#   ('электрических', 0.8057737),
#   ('требования', 0.80522734)],
#  11: [('программист', 0.86299086),
#   ('программного', 0.8378843),
#   ('программированием', 0.82975423),
#   ('специальности', 0.8269071),
#   ('профессия', 0.8236486),
#   ('обеспечение', 0.82054055),
#   ('специалист', 0.82049423),
#   ('специальностями', 0.81828904),
#   ('компьютерной', 0.8159512),
#   ('профессиональное', 0.81354284)],
#  12: [('программист', 0.8439468),
#   ('программирование', 0.82654285),
#   ('профессия', 0.82300466),
#   ('навыки', 0.8181992),
#   ('ключевые', 0.8059442),
#   ('конфигурации', 0.8052731),
#   ('требования', 0.7975763),
#   ('умение', 0.7975656),
#   ('1с', 0.79632735),
#   ('профессиональный', 0.7951141)],
#  13: [('стажер', 0.8158568),
#   ('профессия', 0.8044387),
#   ('навыки', 0.80411756),
#   ('разработчик', 0.80271417),
#   ('требования', 0.80042756),
#   ('обязанности', 0.7979544),
#   ('python', 0.7931763),
#   ('ключевые', 0.7931369),
#   ('возможности', 0.79092234),
#   ('карьерного', 0.7899728)],
#  14: [('разработчик', 0.82513505),
#   ('отчетности', 0.8158561),
#   ('аналитиком', 0.8127306),
#   ('разработка', 0.8091756),
#   ('обслуживания', 0.80875295),
#   ('требования', 0.8071084),
#   ('выполнение', 0.80709064),
#   ('данных', 0.8053462),
#   ('аналитических', 0.8042279),
#   ('офис', 0.80387735)],
#  15: [('qliksense', 0.83911085),
#   ('qlikview', 0.82175183),
#   ('аналитик', 0.81886464),
#   ('аналитики', 0.81778765),
#   ('разработчик', 0.81309164),
#   ('аналитика', 0.8116442),
#   ('аналитическое', 0.80885154),
#   ('отчетности', 0.8004368),
#   ('навыки', 0.79537386),
#   ('разработки', 0.7952556)],
#  16: [('микроконтроллеров', 0.85794675),
#   ('микроконтроллеры', 0.8521955),
#   ('микроконтроллерами', 0.8433838),
#   ('программист', 0.8344356),
#   ('программирование', 0.8284723),
#   ('процессоров', 0.81335986),
#   ('программного', 0.8130046),
#   ('разработки', 0.8036114),
#   ('профессия', 0.8019618),
#   ('stm32', 0.7976848)],
#  17: [('программист', 0.8332337),
#   ('программирования', 0.8309705),
#   ('программирование', 0.82839525),
#   ('стажёр', 0.8268385),
#   ('программированию', 0.8233387),
#   ('стажер', 0.82268536),
#   ('навыки', 0.81887233),
#   ('профессия', 0.8172905),
#   ('1с', 0.8012953),
#   ('ключевые', 0.7976576)],
#  18: [('разработчик', 0.8001606),
#   ('консультант', 0.7929449),
#   ('продвинутый', 0.7920494),
#   ('разработки', 0.7918029),
#   ('продвинутое', 0.7900363),
#   ('администрирования', 0.7875331),
#   ('поддержка', 0.78508115),
#   ('серверного', 0.7826845),
#   ('frontend', 0.78139454),
#   ('стабильный', 0.7798846)],
#  19: [('программист', 0.84646326),
#   ('профессия', 0.8216905),
#   ('навыки', 0.81900537),
#   ('ключевые', 0.8143881),
#   ('требования', 0.8016893),
#   ('обязанности', 0.7987793),
#   ('профессиональная', 0.79755056),
#   ('sql', 0.7962822),
#   ('возможности', 0.79491425),
#   ('информации', 0.79412)]}

# %%
topic_model.save(
    "it_bert_topic",
    serialization="pytorch",
    save_ctfidf=True,
    save_embedding_model=embedding_model,
)

# %%
freq = topic_model.get_topic_info()
freq.to_csv("freq.csv", index=False)

# %% [markdown]
# ## Инференс

# %%
loaded_model = BERTopic.load("it_bert_topic", embedding_model=embedding_model)
# Out:
# 2023-12-20 22:00:33,626 - BERTopic - WARNING: You are loading a BERTopic model without explicitly defining an embedding model.If you want to also load in an embedding model, make sure to useBERTopic.load(my_model, embedding_model=my_embedding_model).

# %%
query = """Программист C++, Web-программист, разработчик аппаратуры,.Опыт работы 5 лет 8 месяцев  Март 2019 — по настоящее время 3 месяца Удаленная работа Обнинск Web-программист Доработка сайта www.autolarek24.ru  Октябрь 2013 — по настоящее время 5 лет 8 месяцев АО «ГНЦ РФ – ФЭИ» Обнинск , www.ippe.ru Энергетика ... Атомная энергетика (генерация электроэнергии, АЭС) Инженер-программист Разработка ПО для операционных систем жесткого реального времени. Разработка драйверов, многопоточных приложений, клиент-серверных приложений. Разработка микропроцессорных систем. Работа с промышленными интерфейсами и протоколами: ModBus, CAN, RS422/485. Разработка документации ПО. Работа с измерительной аппаратурой с очень высокой точностью измерения и написание ПО для мониторинга и фильтрации измерений, а так же участие в разработке, настройке и тестировании данной аппаратуры.  Июнь 2017 — Ноябрь  2017 6 месяцев ООО "Персона" Обнинск Информационные технологии, системная интеграция, интернет ... Разработка программного обеспечения Веб-разработчик Разработка веб-сайтов, концепция MVC, командная разработка (Git), Laravel. Проект www.combeep.com"""

# %%
topics, predicts = loaded_model.transform(query)

# %% [markdown]
# Достанем документы

# %%
docs = pd.read_csv("freq.csv")
docs.head()
# Out:
#    Topic  Count                                               Name  \
# 0     -1    271  -1_программист_программирования_разработчик_пр...
# 1      0    639  0_программист_программирования_программировани...
# 2      1     50         1_программист_профессия_навыки_разработчик
# 3      2     49               2_курсов_обучение_обучения_обучающих
# 4      3     45         3_программист_программ_фрезерные_фрезерных
#
#                                       Representation  \
# 0  ['программист', 'программирования', 'разработч...
# 1  ['программист', 'программирования', 'программи...
# 2  ['программист', 'профессия', 'навыки', 'разраб...
# 3  ['курсов', 'обучение', 'обучения', 'обучающих'...
# 4  ['программист', 'программ', 'фрезерные', 'фрез...
#
#                                  Representative_Docs
# 0  ['Профессия: Программист/Разработчик C#/.NET. ...
# 1  ['Профессия: Разработчик 1С (удаленно). Ключев...
# 2  ['Профессия: Разработчик Python. Ключевые навы...
# 3  ['Профессия: Разработчик электронных курсов Is...
# 4  ['Профессия: Программист станков с ЧПУ. Ключев...

# %%
pprint(docs[docs["Topic"] == topics[0]])
# Out:
#    Topic  Count                                               Name  \
# 1      0    639  0_программист_программирования_программировани...
#
#                                       Representation  \
# 1  ['программист', 'программирования', 'программи...
#
#                                  Representative_Docs
# 1  ['Профессия: Разработчик 1С (удаленно). Ключев...

# %% [markdown]
# ## Вывод

# %% [markdown]
# Качество поиска нас не устраивает, будем пробовать другие подходы
